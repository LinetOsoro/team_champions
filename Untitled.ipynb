# %%
# Import Dependencies
import random
import pandas as pd
import numpy as np
import os

# %%
# load data csv
citi_bike1_df= pd.read_csv("JC-202301-citibike-tripdata.csv")
citi_bike1_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
citi_bike2_df= pd.read_csv("JC-202302-citibike-tripdata.csv")
citi_bike2_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  557150C42CBD584B  classic_bike  2023-02-16 18:05:38  2023-02-16 18:13:47
# 1  9F1B2C0BCD476C66  classic_bike  2023-02-15 19:20:33  2023-02-15 19:27:06
# 2  4A4A29A7C1B54278  classic_bike  2023-02-18 14:58:16  2023-02-18 15:06:15
# 3  BBF4E1D39D41D78C  classic_bike  2023-02-24 15:16:12  2023-02-24 15:24:17
# 4  3CECAA17C4ABBF30  classic_bike  2023-02-16 18:05:02  2023-02-16 18:05:04
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1  Mama Johnson Field - 4 St & Jackson St            HB404
# 2  Mama Johnson Field - 4 St & Jackson St            HB404
# 3  Mama Johnson Field - 4 St & Jackson St            HB404
# 4  Mama Johnson Field - 4 St & Jackson St            HB404
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743190
# ...

# %%
citi_bike3_df= pd.read_csv("JC-202303-citibike-tripdata.csv")
citi_bike3_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  38F943EA06A4E54F  electric_bike  2023-03-25 09:20:57  2023-03-25 09:32:10
# 1  C76EFC4C3B771E88  electric_bike  2023-03-15 07:55:41  2023-03-15 08:07:44
# 2  02C7BC83975952E6  electric_bike  2023-03-20 08:50:11  2023-03-20 09:00:37
# 3  DB0FB572E0AA9C36  electric_bike  2023-03-02 10:17:07  2023-03-02 10:27:22
# 4  A238B2BDD1072D52  electric_bike  2023-03-04 09:13:23  2023-03-04 09:25:30
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 1    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 2    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 3    Jersey & 6th St            JC027     Glenwood Ave          JC094
# 4    Jersey & 6th St            JC027     Glenwood Ave          JC094
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
citi_bike4_df= pd.read_csv("JC-202304-citibike-tripdata.csv")
citi_bike4_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  59B1078FC3455D5B  electric_bike  2023-04-02 14:50:55  2023-04-02 15:01:24
# 1  84365D599B6E002E  electric_bike  2023-04-15 21:08:54  2023-04-16 10:54:44
# 2  A4F033EAA7810781   classic_bike  2023-04-17 10:35:11  2023-04-17 10:37:53
# 3  E9051DFD91E516BF   classic_bike  2023-04-07 12:19:31  2023-04-07 12:21:52
# 4  0F6D86AEC1B29205   classic_bike  2023-04-07 12:28:21  2023-04-07 12:30:23
#
#   start_station_name start_station_id  end_station_name end_station_id  \
# 0      Hamilton Park            JC009     Hamilton Park          JC009
# 1      Hamilton Park            JC009     Hamilton Park          JC009
# 2      Hamilton Park            JC009  Monmouth and 6th          JC075
# 3      Hamilton Park            JC009  Monmouth and 6th          JC075
# 4      Hamilton Park            JC009  Monmouth and 6th          JC075
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
citi_bike5_df= pd.read_csv("JC-202305-citibike-tripdata.csv")
citi_bike5_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  BC145343639B5E5B   classic_bike  2023-05-31 12:27:28  2023-05-31 12:38:36
# 1  A0CE41F47514FF5C   classic_bike  2023-05-01 18:12:37  2023-05-01 18:29:03
# 2  D588077E3D7E2AFD  electric_bike  2023-05-28 17:37:58  2023-05-28 18:39:39
# 3  89AC48A5584B2DB4   classic_bike  2023-05-27 21:01:37  2023-05-27 21:13:16
# 4  709E0B11AB4A0E6C   classic_bike  2023-05-22 12:38:54  2023-05-22 13:02:13
#
#   start_station_name start_station_id       end_station_name end_station_id  \
# 0     Pershing Field            JC024           Newport PATH          JC066
# 1     Pershing Field            JC024  Baldwin at Montgomery          JC020
# 2     Pershing Field            JC024         Pershing Field          JC024
# 3     Pershing Field            JC024           Manila & 1st          JC082
# 4     Pershing Field            JC024           Jersey & 3rd          JC074
#
# ...

# %%
citi_bike6_df= pd.read_csv("JC-202306-citibike-tripdata.csv")
citi_bike6_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27  2023-06-27 16:10:27
# 1  9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58  2023-06-24 10:55:27
# 2  C91293605D4BEC07  electric_bike  2023-06-04 20:30:13  2023-06-04 20:34:31
# 3  2920063442116A46   classic_bike  2023-06-08 19:10:06  2023-06-08 19:13:05
# 4  E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51  2023-06-23 19:17:50
#
#       start_station_name start_station_id  end_station_name end_station_id  \
# 0                Hilltop            JC019   Christ Hospital          JC034
# 1  Baldwin at Montgomery            JC020     Hamilton Park          JC009
# 2                Hilltop            JC019      Brunswick St          JC023
# 3  Baldwin at Montgomery            JC020       Astor Place          JC077
# 4  Baldwin at Montgomery            JC020  Adams St & 11 St          HB507
#
# ...

# %%
citi_bike7_df= pd.read_csv("JC-202307-citibike-tripdata.csv")
citi_bike7_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  7A68381621C25F78   classic_bike  2023-07-17 17:16:34  2023-07-17 17:20:52
# 1  0F814CA67B2FA120   classic_bike  2023-07-26 19:40:15  2023-07-26 19:44:37
# 2  775A38967EBF5FB4  electric_bike  2023-07-01 12:12:22  2023-07-01 12:27:45
# 3  D93B742DCE1C1447   classic_bike  2023-07-20 19:10:18  2023-07-20 19:17:22
# 4  AA7A6863B4B92169  electric_bike  2023-07-07 19:33:59  2023-07-07 19:58:17
#
#       start_station_name start_station_id  \
# 0            Astor Place            JC077
# 1        Adams St & 2 St            HB407
# 2        McGinley Square            JC055
# 3  Baldwin at Montgomery            JC020
# 4  Baldwin at Montgomery            JC020
#
#                          end_station_name end_station_id  start_lat  \
# 0                 Communipaw & Berry Lane          JC084  40.719225
# 1           9 St HBLR - Jackson St & 8 St          HB305  40.739727
# ...

# %%
citi_bike8_df= pd.read_csv("JC-202308-citibike-tripdata.csv")
citi_bike8_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E2E964A161F786AB  classic_bike  2023-08-07 19:37:47  2023-08-07 19:41:14
# 1  0660F2E48E3BB87F  classic_bike  2023-08-01 13:16:22  2023-08-01 13:26:02
# 2  940FC7C675232897  classic_bike  2023-08-15 17:28:23  2023-08-15 17:50:35
# 3  E967660CC5CD585B  classic_bike  2023-08-01 12:44:24  2023-08-01 12:49:45
# 4  D997CB0B855FE2D6  classic_bike  2023-08-08 12:31:16  2023-08-08 12:40:18
#
#            start_station_name start_station_id  \
# 0             6 St & Grand St            HB302
# 1             6 St & Grand St            HB302
# 2            Heights Elevator            JC059
# 3  Hoboken Ave at Monmouth St            JC105
# 4  Hoboken Ave at Monmouth St            JC105
#
#                           end_station_name end_station_id  start_lat  \
# 0                       Madison St & 10 St          HB503  40.744398
# 1                          6 St & Grand St          HB302  40.744398
# ...

# %%
citi_bike9_df= pd.read_csv("JC-202309-citibike-tripdata.csv")
citi_bike9_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  4052081EAF41D252  classic_bike  2023-09-01 17:25:27  2023-09-01 17:31:13
# 1  330043C418DD78E3  classic_bike  2023-09-01 12:57:39  2023-09-01 13:08:50
# 2  4D0F3462818482CF  classic_bike  2023-09-28 08:52:24  2023-09-28 09:15:37
# 3  BF4A3EBF9352E283  classic_bike  2023-09-02 15:25:33  2023-09-02 15:57:11
# 4  957FA73CA6E0C552  classic_bike  2023-09-14 16:46:42  2023-09-14 17:01:18
#
#       start_station_name start_station_id       end_station_name  \
# 0  Baldwin at Montgomery            JC020     Liberty Light Rail
# 1  Baldwin at Montgomery            JC020            Exchange Pl
# 2  Baldwin at Montgomery            JC020  Baldwin at Montgomery
# 3  Baldwin at Montgomery            JC020  Baldwin at Montgomery
# 4  Baldwin at Montgomery            JC020            Paulus Hook
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
citi_bike10_df= pd.read_csv("JC-202310-citibike-tripdata.csv")
citi_bike10_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  56269E94B2206375  classic_bike  2023-10-31 11:52:42  2023-10-31 12:03:33
# 1  2B2F6514026F5C68  classic_bike  2023-10-16 08:24:33  2023-10-16 08:35:28
# 2  3716C0E2166FE548  classic_bike  2023-10-21 11:46:26  2023-10-21 11:56:30
# 3  E06BF0A228598DDF  classic_bike  2023-10-26 09:42:42  2023-10-26 09:51:28
# 4  1EA3E3FFB17B6B16  classic_bike  2023-10-22 13:20:54  2023-10-22 15:00:09
#
#   start_station_name start_station_id  end_station_name end_station_id  \
# 0    McGinley Square            JC055  Marin Light Rail          JC013
# 1        Astor Place            JC077     Grove St PATH          JC115
# 2    McGinley Square            JC055     Grove St PATH          JC115
# 3        Astor Place            JC077  Marin Light Rail          JC013
# 4    McGinley Square            JC055     Grove St PATH          JC115
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
citi_bike11_df= pd.read_csv("JC-202311-citibike-tripdata.csv")
citi_bike11_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  1156A0D0E2EB60CB  classic_bike  2023-11-19 12:08:48  2023-11-19 12:28:53
# 1  9A6D99BAED3AE106  classic_bike  2023-11-05 18:21:56  2023-11-05 18:25:36
# 2  CC3F75A6310A2625  classic_bike  2023-11-12 11:36:41  2023-11-12 11:42:04
# 3  3BF4E21F0D5BCB98  classic_bike  2023-11-08 15:04:23  2023-11-08 15:20:23
# 4  1B7E5ADCABC46F0E  classic_bike  2023-11-22 09:08:22  2023-11-22 09:14:23
#
#                        start_station_name start_station_id  \
# 0                          Jackson Square            JC063
# 1                      Madison St & 10 St            HB503
# 2                      Madison St & 10 St            HB503
# 3                          Jackson Square            JC063
# 4  Mama Johnson Field - 4 St & Jackson St            HB404
#
#                          end_station_name end_station_id  start_lat  \
# 0                   Baldwin at Montgomery          JC020  40.711130
# ...

# %%
citi_bike12_df= pd.read_csv("JC-202312-citibike-tripdata.csv")
citi_bike12_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  DAE3C13A5FAAB089  classic_bike  2023-12-29 16:02:20  2023-12-29 16:10:17
# 1  1EC6BE46ACF2DE11  classic_bike  2023-12-06 01:58:32  2023-12-06 02:04:48
# 2  105CA439B9CBF57C  classic_bike  2023-12-06 20:15:11  2023-12-06 20:21:02
# 3  DC1C46F6090FA1DB  classic_bike  2023-12-09 13:54:19  2023-12-09 13:56:48
# 4  04EAEAAD6D32A664  classic_bike  2023-12-02 17:30:34  2023-12-02 17:37:26
#
#   start_station_name start_station_id         end_station_name end_station_id  \
# 0       Brunswick St            JC023  Communipaw & Berry Lane          JC084
# 1       Brunswick St            JC023              Oakland Ave          JC022
# 2       Brunswick St            JC023              Oakland Ave          JC022
# 3       Brunswick St            JC023             Manila & 1st          JC082
# 4       Brunswick St            JC023           Riverview Park          JC057
#
# ...

# %%
# combine 
combined_df = pd.concat([citi_bike1_df, citi_bike2_df, citi_bike3_df, citi_bike4_df, citi_bike5_df, citi_bike6_df, citi_bike7_df, citi_bike8_df, citi_bike9_df, citi_bike10_df, citi_bike11_df, citi_bike12_df], axis=0)
combined_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
combined_df = pd.concat([citi_bike1_df, citi_bike2_df, citi_bike3_df, citi_bike4_df, citi_bike5_df, citi_bike6_df], axis=0)
combined_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
combined1_df = pd.concat([citi_bike7_df, citi_bike8_df, citi_bike9_df, citi_bike10_df, citi_bike11_df, citi_bike12_df], axis=0)
combined1_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  7A68381621C25F78   classic_bike  2023-07-17 17:16:34  2023-07-17 17:20:52
# 1  0F814CA67B2FA120   classic_bike  2023-07-26 19:40:15  2023-07-26 19:44:37
# 2  775A38967EBF5FB4  electric_bike  2023-07-01 12:12:22  2023-07-01 12:27:45
# 3  D93B742DCE1C1447   classic_bike  2023-07-20 19:10:18  2023-07-20 19:17:22
# 4  AA7A6863B4B92169  electric_bike  2023-07-07 19:33:59  2023-07-07 19:58:17
#
#       start_station_name start_station_id  \
# 0            Astor Place            JC077
# 1        Adams St & 2 St            HB407
# 2        McGinley Square            JC055
# 3  Baldwin at Montgomery            JC020
# 4  Baldwin at Montgomery            JC020
#
#                          end_station_name end_station_id  start_lat  \
# 0                 Communipaw & Berry Lane          JC084  40.719225
# 1           9 St HBLR - Jackson St & 8 St          HB305  40.739727
# ...

# %%
combined_df.to_csv('out.csv', index=False)

# %%
combined1_df.to_csv('out.csv', index=False)
